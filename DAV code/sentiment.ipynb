# %%
import re
import pandas as pd

class SentimentAnalyzer:
    """
    A lexicon-based sentiment analysis tool.
    """
    def __init__(self):
        # Basic lexicon - expand these lists as needed
        self.positive_words = {'good', 'great', 'excellent', 'happy', 'love', 'best', 'awesome', 'nice'}
        self.negative_words = {'bad', 'terrible', 'worst', 'sad', 'hate', 'awful', 'poor', 'fail'}

    def clean_text(self, text):
        return re.sub(r'[^a-z\s]', '', str(text).lower()).split()

    def analyze(self, text):
        words = self.clean_text(text)
        pos_count = sum(1 for w in words if w in self.positive_words)
        neg_count = sum(1 for w in words if w in self.negative_words)
        
        if pos_count > neg_count: return "Positive"
        elif neg_count > pos_count: return "Negative"
        return "Neutral"

# --- CONFIGURATION ---
FILE_PATH = "IMDB-Dataset.csv"
TEXT_COL = "review"

if __name__ == "__main__":
    analyzer = SentimentAnalyzer()
    sample = "This is the best and most awesome tool ever!"
    print(f"Text: {sample}")
    print(f"Sentiment: {analyzer.analyze(sample)}")
# Out:
# Text: This is the best and most awesome tool ever!
# Sentiment: Positive
